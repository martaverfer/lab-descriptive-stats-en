# %% [markdown]
# # Before you start :
#    - These exercises are related to the Subsetting and Descriptive Stats lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
# import libraries here
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from scipy.stats import chi2_contingency
from scipy.stats.contingency import association

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### In this challenge we will use the `Temp_States.csv` file.
#
# #### First import it into a data frame called `temp`.

# %%
# YOUR CODE HERE
data = pd.read_csv('Temp_States.csv')
temp = data.copy()

# %% [markdown]
# #### Print `temp`

# %%
# your solution here
print(temp)
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the Temp dataframe. What type of data do we have? Comment your result.

# %%
# YOUR CODE HERE
temp.dtypes

# We have object for City and State which are strings and Categorical variables
# On the other hand we have float type for Temperature which is a continuous numerical variable
# Out:
# City            object
# State           object
# Temperature    float64
# dtype: object

# %% [markdown]
# #### Select the rows where state is New York

# %%
# YOUR CODE HERE
temp_ny = temp[temp["State"] == "New York"]
temp_ny
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### What is the average of the temperature of cities in New York?

# %%
# YOUR CODE HERE
temp_ny_mean = temp_ny["Temperature"].mean()
temp_ny_mean
# Out:
# 10.74074074074074

# %% [markdown]
# #### We want to know cities and states with Temperature above 15 degress Celcius

# %%
# your answer here
temp_above_15 = temp[temp["Temperature"] > 15.0]
temp_above_15
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222
# 5    Treton   New Jersey    22.222222
# 6    Newark   New Jersey    20.000000

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degress Celcius

# %%
# YOUR CODE HERE
temp_above_15["City"]
# Out:
# 0         NYC
# 3    Hartford
# 5      Treton
# 6      Newark
# Name: City, dtype: object

# %% [markdown]
# #### We want to know which cities have a temperature above 15 degrees Celcius and below 20 degrees Celcius
#
# *Hint: First write the condition then select the rows.*

# %%
# YOUR CODE HERE
condition = (temp["Temperature"] > 15.0) & (temp["Temperature"] < 20.0 )
temp_between = temp[condition]
temp_between
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222

# %%
temp['State'].value_counts()
# Out:
# State
# New York       3
# Connecticut    2
# New Jersey     2
# Name: count, dtype: int64

# %% [markdown]
# #### Find the mean and the standard deviation of the temperature of each state.
#
# *Hint: Use functions from Data Manipulation lesson*

# %%
# YOUR CODE HERE
st_temp = temp.groupby("State")["Temperature"].agg(["mean","std"]).round(2)
st_temp
# Out:
#               mean   std
# State
# Connecticut  15.83  1.96
# New Jersey   21.11  1.57
# New York     10.74  8.13

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Load the `employee.csv` file into a DataFrame. Call the dataframe `employee`

# %%
# YOUR CODE HERE
data1 = pd.read_csv('Employee.csv')
employee = data1.copy()
employee
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 6  Carlos         IT    Master      M         VP      8      70
# 7   Pedro         IT       Phd      M  associate      7      60
# 8     Ana         HR    Master      F         VP      8      70

# %% [markdown]
# #### Explore the data types of the Temp dataframe. Comment your results

# %%
# YOUR CODE HERE
employee.dtypes
# Out:
# Name          object
# Department    object
# Education     object
# Gender        object
# Title         object
# Years          int64
# Salary         int64
# dtype: object

# %%
# We have Name, Department, Education, Gender and Title that are object type, they are strings and are Categorical variables.
# In this group Education is Ordinal whereas the rest are Nominal
# Except from Name, all of the have unique values like the following:

# %%
# Department
employee["Department"].unique()
# Out:
# array(['IT', 'HR', 'Sales'], dtype=object)

# %%
# Education
employee["Education"].unique()
# Out:
# array(['Bachelor', 'Master', 'Phd'], dtype=object)

# %%
# Gender
employee["Gender"].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
# Title
employee["Title"].unique()
# Out:
# array(['analyst', 'associate', 'VP'], dtype=object)

# %%
# On the other hand we ahve two Numercial Discrete variables as ints
# Years and Salary
# We can say Salary is discrete because here the salaries are associated with the Title and Education
# For that Salary can only be limited to certain values

# %% [markdown]
# #### Show visually the frequency distribution (histogram) of the employee dataset. In few words describe these histograms?

# %%
# your answer here
# Since all of them are cat or num discreate variables what it would be more correct would be to use bar plots instead of histograms
employee
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 6  Carlos         IT    Master      M         VP      8      70
# 7   Pedro         IT       Phd      M  associate      7      60
# 8     Ana         HR    Master      F         VP      8      70

# %%
# YOUR CODE HERE
color = '#FF6347'

# grid size
nrows, ncols = 2, 4  # adjust for your number of features

fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(15, 9))

axes = axes.flatten()

# Plot each numerical feature
for i, ax in enumerate(axes):
    if i >= len(employee.columns):
        ax.set_visible(False)  # hide unesed plots
        continue
    ax.hist(employee.iloc[:, i], bins=30, color=color, edgecolor='black')
    ax.set_title(employee.columns[i])

plt.tight_layout()
plt.show()

# %%
# YOUR CODE HERE
color = '#FF6347'

# grid size
nrows, ncols = 2, 4  # adjust for your number of features

fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(15, 9))

axes = axes.flatten()

# Plot each numerical feature
for i, ax in enumerate(axes):
    if i >= len(employee.columns):
        ax.set_visible(False)  # hide unesed plots
        continue
    value_counts = employee.iloc[:, i].value_counts()  # Count the unique values in the column
    value_counts.plot(kind='bar', color=color, edgecolor='black', ax=ax)
    ax.set_title(employee.columns[i])
    ax.set_xlabel(employee.columns[i])
    ax.set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### What's the average salary in this company?

# %%
# YOUR CODE HERE
mean_salary = employee["Salary"].mean()
mean_salary
# Out:
# 48.888888888888886

# %% [markdown]
# #### What's the highest salary?

# %%
# YOUR CODE HERE
max_salary = employee["Salary"].max()
max_salary
# Out:
# 70

# %% [markdown]
# #### What's the lowest salary?

# %%
# YOUR CODE HERE
min_salary = employee["Salary"].min()
min_salary
# Out:
# 30

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
# YOUR CODE HERE
name_low_employee = employee[employee["Salary"] == min(employee["Salary"])]["Name"]
name_low_employee
# Out:
# 1    Maria
# 2    David
# Name: Name, dtype: object

# %% [markdown]
# #### Could you give all the information about an employee called David?

# %%
# YOUR CODE HERE
d_employee = employee[employee["Name"] == 'David']
d_employee
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give only David's salary?

# %%
# YOUR CODE HERE
d_salary_employee = employee[employee["Name"] == 'David']['Salary']
d_salary_employee
# Out:
# 2    30
# Name: Salary, dtype: int64

# %% [markdown]
# #### Print all the rows where job title is associate

# %%
# YOUR CODE HERE
associate_employee = employee[employee["Title"] == 'associate']
associate_employee
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 7   Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Print the first 3 rows of your dataframe
#
# ##### Tip : There are 2 ways to do it. Do it both ways

# %%
# YOUR CODE HERE
employee.head(3)
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %%
# YOUR CODE HERE
employee.iloc[:3]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Find the employees who's title is associate and the salary above 55?

# %%
# YOUR CODE HERE
associate_employee = employee[(employee["Title"] == 'associate') & (employee["Salary"] > 55)]
associate_employee
# Out:
#     Name Department Education Gender      Title  Years  Salary
# 7  Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Group the employees based on their number of years of employment. What are the average salaries in each group?

# %%
# YOUR CODE HERE
years_employee = employee.groupby("Years")["Salary"].mean()
years_employee
# Out:
# Years
# 1    35.000000
# 2    38.333333
# 3    55.000000
# 4    35.000000
# 7    60.000000
# 8    70.000000
# Name: Salary, dtype: float64

# %% [markdown]
# ####  What is the average Salary per title?

# %%
# YOUR CODE HERE
title_employee = employee.groupby("Title")["Salary"].mean()
title_employee
# Out:
# Title
# VP           70.000000
# analyst      32.500000
# associate    56.666667
# Name: Salary, dtype: float64

# %% [markdown]
# #### Show a visual summary of the data using boxplot. What Are the First and Third Quartiles? Comment your results.
#
# * Hint : Quantiles vs Quartiles*
# In Probability and Statistics, quantiles are cut points dividing the range of a probability distribution into continuous intervals with equal probabilities. When division is into four parts the values of the variate corresponding to 25%, 50% and 75% of the total distribution are called quartiles.

# %%
num = employee.select_dtypes(include="number")

# YOUR CODE HERE
color = '#0072B2'

# grid size
nrows, ncols = 1, 2

fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(8, 5))

axes = axes.flatten()

for i, ax in enumerate(axes):
    if i >= len(num.columns):
        ax.set_visible(False)
        continue
    ax.boxplot(num.iloc[:, i], vert=False, patch_artist=True,
               boxprops=dict(facecolor=color, color='black'),
               medianprops=dict(color='yellow'), whiskerprops=dict(color='black'),
               capprops=dict(color='black'), flierprops=dict(marker='o', color='red', markersize=5))
    ax.set_title(num.columns[i], fontsize=10)
    ax.tick_params(axis='x', labelsize=8)

plt.tight_layout()
plt.show()

# %%
# print first quartile here
first_q_salary = employee["Salary"].quantile(0.25)
first_q_years = employee["Years"].quantile(0.25)
print(first_q_salary)
print(first_q_years)
# Out:
# 35.0
# 2.0

# %%
# print third quartile here
third_q_salary = employee["Salary"].quantile(0.75)
third_q_years = employee["Years"].quantile(0.75)
print(third_q_salary)
print(third_q_years)
# Out:
# 60.0
# 7.0

# %%
# the first and thrid quartile can be spotted in the boxplot since it is where the box plot starts and ends
# between the first and third quartile is were we can found most of our data

# %% [markdown]
# #### Is the mean salary per gender different?

# %%
# your answer here
gender_employee = employee.groupby("Gender")["Salary"].mean()
gender_employee
# Out:
# Gender
# F    47.5
# M    50.0
# Name: Salary, dtype: float64

# %% [markdown]
# #### Find the minimum, mean and the maximum of all numeric columns for each Department.
#
# ##### Hint: Use functions from Data Manipulation lesson

# %%
# your answer here
department_sal_year = employee.groupby("Department")[["Salary", "Years"]].agg(["min","mean","max"]).round(2)
department_sal_year
# Out:
#            Salary            Years
#               min   mean max   min  mean max
# Department
# HR             30  45.00  70     2  4.67   8
# IT             30  48.75  70     1  4.50   8
# Sales          55  55.00  55     2  2.50   3

# %% [markdown]
# ### Bonus Question
#
# #### For each department, compute the difference between the maximal salary and the minimal salary.
#
# ##### * Hint: try using `agg` or `apply` and `lambda`*

# %%
# your answer here
department_diff = employee.groupby("Department")[["Salary"]].agg(lambda x: round(x.max() - x.min(), 2))
department_diff
# Out:
#             Salary
# Department
# HR              40
# IT              40
# Sales            0

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Open the Orders.csv dataset. Name your dataset orders

# %%
# your answer here
data2 = pd.read_csv('Orders.csv')
orders = data2.copy()
orders
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 0                0     536365    85123A  2010     12    3     8
# 1                1     536365     71053  2010     12    3     8
# 2                2     536365    84406B  2010     12    3     8
# 3                3     536365    84029G  2010     12    3     8
# 4                4     536365    84029E  2010     12    3     8
# ...            ...        ...       ...   ...    ...  ...   ...
# 397919      541904     581587     22613  2011     12    5    12
# 397920      541905     581587     22899  2011     12    5    12
# 397921      541906     581587     23254  2011     12    5    12
# 397922      541907     581587     23255  2011     12    5    12
# 397923      541908     581587     22138  2011     12    5    12
#
#                                 Description  Quantity          InvoiceDate  \
# 0        white hanging heart t-light holder         6  2010-12-01 08:26:00
# ...

# %% [markdown]
# #### Explore your dataset by looking at the data types and the summary statistics. Comment your results

# %%
# your answer here
orders.dtypes
# Out:
# Unnamed: 0        int64
# InvoiceNo         int64
# StockCode        object
# year              int64
# month             int64
# day               int64
# hour              int64
# Description      object
# Quantity          int64
# InvoiceDate      object
# UnitPrice       float64
# CustomerID        int64
# Country          object
# amount_spent    float64
# dtype: object

# %%
# your answer here
num = orders.select_dtypes(include="number")
num.describe().round(2)
# Out:
#        Unnamed: 0  InvoiceNo       year      month        day       hour  \
# count   397924.00  397924.00  397924.00  397924.00  397924.00  397924.00
# mean    278465.22  560617.13    2010.93       7.61       3.61      12.73
# std     152771.37   13106.17       0.25       3.42       1.93       2.27
# min          0.00  536365.00    2010.00       1.00       1.00       6.00
# 25%     148333.75  549234.00    2011.00       5.00       2.00      11.00
# 50%     284907.50  561893.00    2011.00       8.00       3.00      13.00
# 75%     410079.25  572090.00    2011.00      11.00       5.00      14.00
# max     541908.00  581587.00    2011.00      12.00       7.00      20.00
#
#         Quantity  UnitPrice  CustomerID  amount_spent
# count  397924.00  397924.00   397924.00     397924.00
# mean       13.02       3.12    15294.32         22.39
# std       180.42      22.10     1713.17        309.06
# min         1.00       0.00    12346.00          0.00
# ...

# %%
# Most of our data belogs to the numerical data type
# We have the continuous data: UnitPrice and amount_spent
# On the other hand we have the numerical discrete: unnamed: 0, invoiceNo, year, month, day, hour, quantity and CustomerID

# %% [markdown]
# ####  What is the average Purchase Price?

# %%
# your answer here
mean_purchase = orders["amount_spent"].mean()
mean_purchase
# Out:
# 22.394748504739596

# %% [markdown]
# #### What were the highest and lowest purchase prices?

# %%
# your answer here
min_purchase = orders["amount_spent"].min()
min_purchase
# Out:
# 0.0

# %%
# your answer here
max_purchase = orders["amount_spent"].max()
max_purchase
# Out:
# 168469.6

# %% [markdown]
# #### Select all the customers we have in Spain

# %%
# your answer here
spain_cust = orders[orders['Country'] == 'Spain']
spain_cust
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 4250          6421     536944     22383  2010     12    5    12
# 4251          6422     536944     22384  2010     12    5    12
# 4252          6423     536944     20727  2010     12    5    12
# 4253          6424     536944     20725  2010     12    5    12
# 4254          6425     536944     20728  2010     12    5    12
# ...            ...        ...       ...   ...    ...  ...   ...
# 394733      535271     581193     23291  2011     12    3    17
# 394734      535272     581193    85232D  2011     12    3    17
# 394735      535273     581193     22721  2011     12    3    17
# 394736      535274     581193     23241  2011     12    3    17
# 394737      535275     581193     23247  2011     12    3    17
#
#                           Description  Quantity          InvoiceDate  \
# 4250          lunch bag suki  design         70  2010-12-03 12:20:00
# ...

# %% [markdown]
# #### How many customers do we have in Spain?
# ##### Hint : Use value_counts()

# %%
num_cust_spain = spain_cust.shape[0]
num_cust_spain
# Out:
# 2485

# %% [markdown]
# #### Select all the customers who have bought more than 50 items ?

# %%
# your answer here
items_50 = orders[orders['Quantity'] > 50]
items_50
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 46              46     536371     22086  2010     12    3     9
# 83              83     536376     21733  2010     12    3     9
# 96              96     536378     21212  2010     12    3     9
# 102            102     536378    85071B  2010     12    3     9
# 174            176     536386    85099C  2010     12    3     9
# ...            ...        ...       ...   ...    ...  ...   ...
# 397720      541702     581566     23404  2011     12    5    11
# 397721      541703     581567     21417  2011     12    5    11
# 397729      541711     581567     21326  2011     12    5    11
# 397761      541746     581571     23167  2011     12    5    12
# 397882      541867     581584     20832  2011     12    5    12
#
#                                Description  Quantity          InvoiceDate  \
# 46         paper chain kit 50's christmas         80  2010-12-01 09:00:00
# ...

# %% [markdown]
# #### Select orders from Spain that are above 50 items

# %%
# your answer here
spain_50 = orders[(orders['Quantity'] > 50) & (orders['Country'] == 'Spain')]
spain_50
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 4250          6421     536944     22383  2010     12    5    12
# 4251          6422     536944     22384  2010     12    5    12
# 4252          6423     536944     20727  2010     12    5    12
# 4253          6424     536944     20725  2010     12    5    12
# 4254          6425     536944     20728  2010     12    5    12
# 32454        52416     540785    84997B  2011      1    2    11
# 32455        52417     540785    84997D  2011      1    2    11
# 32456        52418     540785    84997C  2011      1    2    11
# 32457        52419     540785    84997A  2011      1    2    11
# 91155       136767     547972     22383  2011      3    1    16
# 91156       136768     547972     22384  2011      3    1    16
# 91159       136771     547972     20728  2011      3    1    16
# 174442      248797     558871     22384  2011      7    1    13
# 174443      248798     558871     20727  2011      7    1    13
# ...

# %% [markdown]
# #### Select all free orders

# %%
# your answer here
free_orders = orders[orders['amount_spent'] == 0.0]
free_orders
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 6914          9302     537197     22841  2010     12    7    14
# 22539        33576     539263     22580  2010     12    4    14
# 25379        40089     539722     22423  2010     12    2    13
# 29080        47068     540372     22090  2011      1    4    16
# 29082        47070     540372     22553  2011      1    4    16
# 34494        56674     541109     22168  2011      1    4    15
# 53788        86789     543599    84535B  2011      2    4    13
# 85671       130188     547417     22062  2011      3    3    10
# 92875       139453     548318     22055  2011      3    3    12
# 97430       145208     548871     22162  2011      4    1    14
# 107192      157042     550188     22636  2011      4    4    18
# 128641      187613     553000     47566  2011      5    4    15
# 137127      198383     554037     22619  2011      5    5    14
# 194648      279324     561284     22167  2011      7    2    12
# ...

# %% [markdown]
# #### Select all orders that are 'lunch bag'
# #### Hint: Use string functions

# %%
# your answer here
descrp_lb = orders[orders['Description'].str.contains('lunch bag', case=False)]
descrp_lb
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 93              93     536378     20725  2010     12    3     9
# 172            174     536385     22662  2010     12    3     9
# 354            363     536401     22662  2010     12    3    11
# 359            368     536401     20725  2010     12    3    11
# 360            369     536401     22382  2010     12    3    11
# ...            ...        ...       ...   ...    ...  ...   ...
# 397465      540436     581486     23207  2011     12    5     9
# 397713      541695     581538     20727  2011     12    5    11
# 397714      541696     581538     20725  2011     12    5    11
# 397877      541862     581581     23681  2011     12    5    12
# 397880      541865     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 93          lunch bag red retrospot        10  2010-12-01 09:37:00       1.65
# ...

# %% [markdown]
# #### Select all orders that are made in 2011 and are 'lunch bag'

# %%
# your answer here
orders_2011_lb = orders[(orders['Description'].str.contains('lunch bag', case=False)) & orders['year'] == 2011]
orders_2011_lb
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, InvoiceNo, StockCode, year, month, day, hour, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country, amount_spent]
# Index: []

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
# your answer here
sns.histplot(spain_cust.amount_spent, bins=500)
plt.show()

# %% [markdown]
# #### Select all orders made in the month of August

# %%
# your answer here
august_orders = orders[orders['month'] == 8]
august_orders
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 199475      285421     561904     22075  2011      8    1     8
# 199476      285422     561904    85049E  2011      8    1     8
# 199477      285423     561905     21385  2011      8    1     9
# 199478      285424     561905    84970L  2011      8    1     9
# 199479      285425     561905    84970S  2011      8    1     9
# ...            ...        ...       ...   ...    ...  ...   ...
# 226483      320688     565067     22644  2011      8    3    17
# 226484      320689     565067     22645  2011      8    3    17
# 226485      320690     565067     22637  2011      8    3    17
# 226486      320691     565067     22646  2011      8    3    17
# 226487      320692     565067     22741  2011      8    3    17
#
#                                 Description  Quantity          InvoiceDate  \
# 199475          6 ribbons elegant christmas        96  2011-08-01 08:30:00
# ...

# %% [markdown]
# #### Select how many orders are made by countries in the month of August
# ##### Hint: Use value_counts()

# %%
# your answer here
orders_by_country = august_orders["Country"].value_counts()
orders_by_country
# Out:
# Country
# United Kingdom     23105
# Germany              795
# EIRE                 593
# France               569
# Netherlands          280
# Switzerland          267
# Spain                252
# Belgium              194
# Israel               171
# Channel Islands      140
# Australia            107
# Italy                 95
# Austria               88
# Norway                77
# Finland               61
# Malta                 55
# Portugal              41
# Sweden                40
# Unspecified           23
# Iceland               22
# Poland                17
# Denmark               16
# Canada                 5
# Name: count, dtype: int64

# %% [markdown]
# #### What's the  average amount of money spent by country

# %%
# your answer here
money_by_country = orders.groupby("Country")["amount_spent"].agg(["mean"]).round(2)
money_by_country
# Out:
#                         mean
# Country
# Australia             116.90
# Austria                25.62
# Bahrain                32.26
# Belgium                20.28
# Brazil                 35.74
# Canada                 24.28
# Channel Islands        27.34
# Cyprus                 22.13
# Czech Republic         33.07
# Denmark                49.88
# EIRE                   36.69
# European Community     21.67
# Finland                32.91
# France                 25.06
# Germany                25.31
# Greece                 32.83
# Iceland                23.68
# Israel                 29.12
# Italy                  23.06
# Japan                 116.56
# Lebanon                37.64
# Lithuania              47.46
# Malta                  24.34
# Netherlands           120.80
# Norway                 33.74
# Poland                 22.23
# Portugal               22.87
# RSA                    17.28
# Saudi Arabia           16.21
# Singapore              95.85
# ...

# %% [markdown]
# #### What's the most expensive item?

# %%
# your answer here
expensive_item = orders.loc[orders['UnitPrice'].idxmax(), 'Description']
expensive_item
# Out:
# 'postage'

# %% [markdown]
# #### What was the average amount spent per year ?

# %%
# your answer here
amount_per_year = orders.groupby("year")["amount_spent"].agg(["mean"]).round(2)
amount_per_year
# Out:
#        mean
# year
# 2010  21.89
# 2011  22.43
